# %% [markdown]
# <img src="../files/misc/logo.png" width=300/>
# <h1 style="color:#872325"> Applied Pandas </h1>

# %% [markdown]
# ![pandas-logo](http://pandas.pydata.org/_static/pandas_logo.png)

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Pandas tiene dos estructuras principales para trabajar con la información: `pandas.Series` y `pandas.DataFrame`.
#
# * Un `pandas.Series` es un arreglo matricial con $n$ elementos del mismo tipo, por otro lado,
# * un `pandas.DataFrame` es una colección de $m$ `pandas.Series` no necesariamente del mismo tipo, pero sí con el mismo número $n$ de elementos.

# %% [markdown]
# ## ¿Cómo crear un Series y un DataFrame desde Python?
# ### Pandas Series

# %%
# Creando un Series
some_data = [i ** i for i in range(5)]
pd.Series(some_data)
# Out:
# 0      1
# 1      1
# 2      4
# 3     27
# 4    256
# dtype: int64

# %%
# Creando un Series y agregando información sobre los datos a trabajar
some_data = [i ** i for i in range(5)]
pd.Series(some_data, name="x_to_x")
# Out:
# 0      1
# 1      1
# 2      4
# 3     27
# 4    256
# Name: x_to_x, dtype: int64

# %%
# Creando un Series y agregando información sobre cada índice y el nombre
# de los datos a trabajar
ages = [21, 23, 30, 19, 3]
names = ["John", "Timmy", "Kenny", "Isaac", "Yann"]
ages = pd.Series(ages, index=names, name="people")
ages
# Out:
# John     21
# Timmy    23
# Kenny    30
# Isaac    19
# Yann      3
# Name: people, dtype: int64

# %% [markdown]
# Al igual que un numpy array, un `Series` contiene información sobre
#
# * El número de dimensiones para un Series (siempre 1)
# * El tamaño de cada dimensión (`shape`)
# * La clase de objeto que contiene el numpy array

# %%
ages.ndim
# Out:
# 1

# %%
ages.shape
# Out:
# (5,)

# %%
ages.dtype
# Out:
# dtype('int64')

# %% [markdown]
# Adicional a estas propiedades, un `Series` contiene el **nombre** de la serie y los **valores** sobres los cuáles se le puede indexar.

# %%
# Nombre de la serie
ages.name
# Out:
# 'people'

# %%
# Valores a indexar de la serie
ages.index
# Out:
# Index(['John', 'Timmy', 'Kenny', 'Isaac', 'Yann'], dtype='object')

# %% [markdown]
# Al ser un `Series` un objeto vectorizable, podemos aplicar operaciones de manera vectorial

# %%
ages / 2
# Out:
# John     10.5
# Timmy    11.5
# Kenny    15.0
# Isaac     9.5
# Yann      1.5
# Name: people, dtype: float64

# %%
np.sqrt(ages)
# Out:
# John     4.582576
# Timmy    4.795832
# Kenny    5.477226
# Isaac    4.358899
# Yann     1.732051
# Name: people, dtype: float64

# %%
np.maximum(ages, 20)
# Out:
# John     21
# Timmy    23
# Kenny    30
# Isaac    20
# Yann     20
# Name: people, dtype: int64

# %%
ages > 10
# Out:
# John      True
# Timmy     True
# Kenny     True
# Isaac     True
# Yann     False
# Name: people, dtype: bool

# %% [markdown]
# ### Pandas DataFrame
# Como se mencionó anteriormente, un pandas `DataFrame` es una colección de $m$ pandas `Series`

# %%
names = ["John", "Timmy", "Kenny", "Yann", "Isaac"]
ages_list = [21, 23, 23, 19, 3]
colors_list = ["teal", "black", "crimson", "yellow", "white"]
amount_list = [10_000, 100_000, 23_000, 5_000, 11_000]

personas = pd.DataFrame({"ages": ages_list,
                         "colors": colors_list,
                         "bank": amount_list}, index=names)
personas
# Out:
#        ages   colors    bank
# John     21     teal   10000
# Timmy    23    black  100000
# Kenny    23  crimson   23000
# Yann     19   yellow    5000
# Isaac     3    white   11000

# %% [markdown]
# # Cargando Información
#
# En la mayoría de la ocasiones cargamos información desde un archivo o base de datos. Pandas cuenta con diversas funciones para cargar información:
#
# ```
# pd.read_clipboard
# pd.read_csv
# pd.read_excel
# pd.read_feather
# pd.read_fwf
# pd.read_gbq
# pd.read_hdf
# pd.read_html
# pd.read_json
# pd.read_msgpack
# pd.read_parquet
# pd.read_pickle
# pd.read_sas
# pd.read_spss
# pd.read_sql
# pd.read_sql_query
# pd.read_sql_table
# pd.read_stata
# pd.read_table
# ```
#
# En el resto de esta sección trabajaremos con datos existentes en archivos y bases de datos.

# %%
from sqlalchemy import create_engine
passw = "maquina271"
engstr = f"mysql+pymysql://nabla123:{passw}@db4free.net:3306/nabla_python"
engine = create_engine(engstr)
conn = engine.connect()

# %%
query = "SELECT * FROM customers"
customers = pd.read_sql(query, conn, index_col="customerNumber")

# %% [markdown]
# ## Métodos Básicos

# %%
# Observamos los primeros 5 valores
customers.head()
# Out:
#                               customerName contactLastName contactFirstName  \
# customerNumber
# 103                      Atelier graphique         Schmitt          Carine
# 112                     Signal Gift Stores            King             Jean
# 114             Australian Collectors, Co.        Ferguson            Peter
# 119                      La Rochelle Gifts         Labrune          Janine
# 121                     Baane Mini Imports      Bergulfsen           Jonas
#
#                        phone                  addressLine1 addressLine2  \
# customerNumber
# 103               40.32.2555                54, rue Royale         None
# 112               7025551838               8489 Strong St.         None
# 114             03 9520 4555             636 St Kilda Road      Level 3
# 119               40.67.8555  67, rue des Cinquante Otages         None
# 121               07-98 9555        Erling Skakkes gate 78         None
#
#                      city     state postalCode    country  \
# customerNumber
# 103                Nantes      None      44000     France
# 112             Las Vegas        NV      83030        USA
# 114             Melbourne  Victoria       3004  Australia
# 119                Nantes      None      44000     France
# 121               Stavern      None       4110     Norway
#
#                 salesRepEmployeeNumber  creditLimit
# customerNumber
# 103                             1370.0      21000.0
# 112                             1166.0      71800.0
# 114                             1611.0     117300.0
# 119                             1370.0     118200.0
# 121                             1504.0      81700.0

# %%
# Observamos los últimos 5 valores
customers.tail()
# Out:
#                                   customerName contactLastName  \
# customerNumber
# 486               Motor Mint Distributors Inc.         Salazar
# 487                   Signal Collectibles Ltd.          Taylor
# 489             Double Decker Gift Stores, Ltd           Smith
# 495                       Diecast Collectables          Franco
# 496                          Kelly's Gift Shop         Snowden
#
#                contactFirstName           phone        addressLine1  \
# customerNumber
# 486                        Rosa      2155559857   11328 Douglas Av.
# 487                         Sue      4155554312   2793 Furth Circle
# 489                     Thomas   (171) 555-7555     120 Hanover Sq.
# 495                     Valarie      6175552555      6251 Ingle Ln.
# 496                        Tony   +64 9 5555500  Arenales 1938 3'A'
#
#                addressLine2          city state postalCode      country  \
# customerNumber
# 486                    None  Philadelphia    PA      71270          USA
# 487                    None      Brisbane    CA      94217          USA
# 489                    None        London  None    WA1 1DP           UK
# 495                    None        Boston    MA      51003          USA
# 496                    None    Auckland    None       None  New Zealand
#
#                 salesRepEmployeeNumber  creditLimit
# customerNumber
# 486                             1323.0      72600.0
# 487                             1165.0      60300.0
# 489                             1501.0      43300.0
# 495                             1188.0      85100.0
# 496                             1612.0     110000.0

# %%
# Estadísticos básicos
customers.describe()
# Out:
#        salesRepEmployeeNumber    creditLimit
# count               100.00000     122.000000
# mean               1395.94000   67659.016393
# std                 165.67193   45043.370751
# min                1165.00000       0.000000
# 25%                1286.00000   42175.000000
# 50%                1370.00000   76700.000000
# 75%                1504.00000   95075.000000
# max                1702.00000  227600.000000

# %%
# .assign regresa una copia del dataframe con una nueva columa
# de la transformación de una o más columnas
def full_name(df):
    full_name = df['contactFirstName'].str.strip()
    full_name = full_name + df['contactLastName']
    return full_name
customers.assign(contact_full_name=full_name)
# Out:
#                                       customerName  contactLastName  \
# customerNumber
# 103                              Atelier graphique          Schmitt
# 112                             Signal Gift Stores             King
# 114                     Australian Collectors, Co.         Ferguson
# 119                              La Rochelle Gifts          Labrune
# 121                             Baane Mini Imports       Bergulfsen
# 124                   Mini Gifts Distributors Ltd.           Nelson
# 125                             Havel & Zbyszek Co  Piestrzeniewicz
# 128                           Blauer See Auto, Co.           Keitel
# 129                                Mini Wheels Co.           Murphy
# 131                              Land of Toys Inc.              Lee
# 141                         Euro+ Shopping Channel           Freyre
# 144                       Volvo Model Replicas, Co         Berglund
# 145                       Danish Wholesale Imports         Petersen
# 146                         Saveley & Henriot, Co.          Saveley
# 148                        Dragon Souveniers, Ltd.        Natividad
# 151                             Muscle Machine Inc            Young
# 157                          Diecast Classics Inc.            Leong
# 161                           Technics Stores Inc.        Hashimoto
# 166                               Handji Gifts& Co        Victorino
# 167                                   Herkku Gifts           Oeztan
# 168                         American Souvenirs Inc           Franco
# 169                              Porto Imports Co.        de Castro
# 171                       Daedalus Designs Imports            Rancé
# 172                      La Corne D'abondance, Co.         Bertrand
# 173                     Cambridge Collectables Co.            Tseng
# 175                                Gift Depot Inc.             King
# 177                           Osaka Souveniers Co.          Kentary
# 181                                Vitachrome Inc.            Frick
# 186                           Toys of Finland, Co.        Karttunen
# 187                                 AV Stores, Co.         Ashworth
# ...                                            ...              ...
# 386                            L'ordine Souveniers           Moroni
# 398                        Tokyo Collectables, Ltd        Shimamura
# 406                              Auto Canal+ Petit          Perrier
# 409                 Stuttgart Collectable Exchange           Müller
# 412                  Extreme Desk Decorations, Ltd            McRoy
# 415             Bavarian Collectables Imports, Co.      Donnermeyer
# 424                           Classic Legends Inc.        Hernandez
# 443                       Feuer Online Stores, Inc            Feuer
# 447                               Gift Ideas Corp.            Lewis
# 448                        Scandinavian Gift Ideas          Larsson
# 450                      The Sharp Gifts Warehouse            Frick
# 452                                Mini Auto Werke           Mendel
# 455                               Super Scale Inc.           Murphy
# 456                                Microscale Inc.             Choi
# 458                     Corrida Auto Replicas, Ltd           Sommer
# 459                               Warburg Exchange          Ottlieb
# 462                               FunGiftIdeas.com          Benitez
# 465                            Anton Designs, Ltd.            Anton
# 471                   Australian Collectables, Ltd         Clenahan
# 473                             Frau da Collezione          Ricotti
# 475                    West Coast Collectables Co.         Thompson
# 477                            Mit Vergnügen & Co.             Moos
# 480                      Kremlin Collectables, Co.          Semenov
# 481                             Raanan Stores, Inc      Altagar,G M
# 484                     Iberia Gift Imports, Corp.             Roel
# 486                   Motor Mint Distributors Inc.          Salazar
# 487                       Signal Collectibles Ltd.           Taylor
# 489                 Double Decker Gift Stores, Ltd            Smith
# 495                           Diecast Collectables           Franco
# 496                              Kelly's Gift Shop          Snowden
#
#                contactFirstName               phone  \
# customerNumber
# 103                     Carine           40.32.2555
# 112                        Jean          7025551838
# 114                       Peter        03 9520 4555
# 119                     Janine           40.67.8555
# 121                      Jonas           07-98 9555
# 124                       Susan          4155551450
# 125                    Zbyszek        (26) 642-7555
# 128                      Roland   +49 69 66 90 2555
# 129                       Julie          6505555787
# 131                        Kwai          2125557818
# 141                      Diego       (91) 555 94 44
# 144                  Christina         0921-12 3555
# 145                      Jytte           31 12 3555
# 146                       Mary           78.32.5555
# 148                        Eric        +65 221 7555
# 151                        Jeff          2125557413
# 157                      Kelvin          2155551555
# 161                        Juri          6505556809
# 166                       Wendy        +65 224 1555
# 167                      Veysel       +47 2267 3215
# 168                       Keith          2035557845
# 169                     Isabel         (1) 356-5555
# 171                    Martine           20.16.1555
# 172                       Marie      (1) 42.34.2555
# 173                       Jerry          6175555555
# 175                       Julie          2035552570
# 177                        Mory    +81 06 6342 5555
# 181                     Michael          2125551500
# 186                       Matti         90-224 8555
# 187                      Rachel      (171) 555-1555
# ...                         ...                 ...
# 386                   Maurizio          0522-556555
# 398                       Akiko     +81 3 3584 0555
# 406                   Dominique      (1) 47.55.6555
# 409                       Rita          0711-555361
# 412                       Sarah         04 499 9555
# 415                     Michael   +49 89 61 08 9555
# 424                       Maria          2125558493
# 443                  Alexander          0342-555176
# 447                         Dan          2035554407
# 448                      Martha        0695-34 6555
# 450                         Sue          4085553659
# 452                     Roland            7675-3555
# 455                      Leslie          2035559545
# 456                          Yu          2125551957
# 458                     Martín       (91) 555 22 82
# 459                       Sven          0241-039123
# 462                     Violeta          5085552555
# 465                      Carmen      +34 913 728555
# 471                        Sean      61-9-3844-6555
# 473                      Franco       +39 022515555
# 475                       Steve          3105553722
# 477                      Hanna           0621-08555
# 480                  Alexander      +7 812 293 0521
# 481                      Raanan    + 972 9 959 8555
# 484                 José Pedro       (95) 555 82 82
# 486                        Rosa          2155559857
# 487                         Sue          4155554312
# 489                     Thomas       (171) 555-7555
# 495                     Valarie          6175552555
# 496                        Tony       +64 9 5555500
#
#                                     addressLine1              addressLine2  \
# customerNumber
# 103                               54, rue Royale                      None
# 112                              8489 Strong St.                      None
# 114                            636 St Kilda Road                   Level 3
# 119                 67, rue des Cinquante Otages                      None
# 121                       Erling Skakkes gate 78                      None
# 124                              5677 Strong St.                      None
# 125                              ul. Filtrowa 68                      None
# 128                                Lyonerstr. 34                      None
# 129                    5557 North Pendale Street                      None
# 131                      897 Long Airport Avenue                      None
# 141                           C/ Moralzarzal, 86                      None
# 144                              Berguvsvägen  8                      None
# 145                                 Vinbæltet 34                      None
# 146                           2, rue du Commerce                      None
# 148                                   Bronz Sok.  Bronz Apt. 3/6 Tesvikiye
# 151                            4092 Furth Circle                 Suite 400
# 157                             7586 Pompton St.                      None
# 161                            9408 Furth Circle                      None
# 166                      106 Linden Road Sandown                 2nd Floor
# 167                              Brehmen St. 121            PR 334 Sentrum
# 168                            149 Spinnaker Dr.                 Suite 101
# 169                       Estrada da saúde n. 58                      None
# 171                     184, chaussée de Tournai                      None
# 172                      265, boulevard Charonne                      None
# 173                               4658 Baden Av.                      None
# 175                          25593 South Bay Ln.                      None
# 177                                1-6-20 Dojima                      None
# 181                            2678 Kingston Rd.                 Suite 101
# 186                                Keskuskatu 45                      None
# 187                            Fauntleroy Circus                      None
# ...                                          ...                       ...
# 386                       Strada Provinciale 124                      None
# 398                               2-2-8 Roppongi                      None
# 406                            25, rue Lauriston                      None
# 409                            Adenauerallee 900                      None
# 412                             101 Lambton Quay                  Level 11
# 415                                 Hansastr. 15                      None
# 424                             5905 Pompton St.                 Suite 750
# 443                                  Heerstr. 22                      None
# 447                             2440 Pompton St.                      None
# 448                                 Åkergatan 24                      None
# 450                               3086 Ingle Ln.                      None
# 452                                 Kirchgasse 6                      None
# 455                     567 North Pendale Street                      None
# 456                    5290 North Pendale Street                 Suite 200
# 458                               C/ Araquil, 67                      None
# 459                                 Walserweg 21                      None
# 462                            1785 First Street                      None
# 465             c/ Gobelas, 19-1 Urb. La Florida                      None
# 471                               7 Allen Street                      None
# 473                        20093 Cologno Monzese       Alessandro Volta 16
# 475                            3675 Furth Circle                      None
# 477                               Forsterstr. 57                      None
# 480                              2 Pobedy Square                      None
# 481                               3 Hagalim Blv.                      None
# 484                                C/ Romero, 33                      None
# 486                            11328 Douglas Av.                      None
# 487                            2793 Furth Circle                      None
# 489                              120 Hanover Sq.                      None
# 495                               6251 Ingle Ln.                      None
# 496                           Arenales 1938 3'A'                      None
#
#                             city     state postalCode      country  \
# customerNumber
# 103                       Nantes      None      44000       France
# 112                    Las Vegas        NV      83030          USA
# 114                    Melbourne  Victoria       3004    Australia
# 119                       Nantes      None      44000       France
# 121                      Stavern      None       4110       Norway
# 124                   San Rafael        CA      97562          USA
# 125                     Warszawa      None     01-012       Poland
# 128                    Frankfurt      None      60528      Germany
# 129                San Francisco        CA      94217          USA
# 131                          NYC        NY      10022          USA
# 141                       Madrid      None      28034        Spain
# 144                        Luleå      None   S-958 22       Sweden
# 145                    Kobenhavn      None       1734      Denmark
# 146                         Lyon      None      69004       France
# 148                    Singapore      None     079903    Singapore
# 151                          NYC        NY      10022          USA
# 157                    Allentown        PA      70267          USA
# 161                   Burlingame        CA      94217          USA
# 166                    Singapore      None     069045    Singapore
# 167                       Bergen      None     N 5804     Norway
# 168                    New Haven        CT      97823          USA
# 169                       Lisboa      None       1756     Portugal
# 171                        Lille      None      59000       France
# 172                        Paris      None      75012       France
# 173                    Cambridge        MA      51247          USA
# 175                  Bridgewater        CT      97562          USA
# 177                      Kita-ku     Osaka   530-0003        Japan
# 181                          NYC        NY      10022          USA
# 186                     Helsinki      None      21240      Finland
# 187                   Manchester      None    EC2 5NT           UK
# ...                          ...       ...        ...          ...
# 386                Reggio Emilia      None      42100        Italy
# 398                    Minato-ku     Tokyo   106-0032        Japan
# 406                        Paris      None      75016       France
# 409                    Stuttgart      None      70563      Germany
# 412                   Wellington      None       None  New Zealand
# 415                       Munich      None      80686      Germany
# 424                          NYC        NY      10022          USA
# 443                      Leipzig      None      04179      Germany
# 447                     Glendale        CT      97561          USA
# 448                       Bräcke      None   S-844 67       Sweden
# 450                     San Jose        CA      94217          USA
# 452                         Graz      None       8010      Austria
# 455                    New Haven        CT      97823          USA
# 456                          NYC        NY      10022          USA
# 458                       Madrid      None      28023        Spain
# 459                       Aachen      None      52066      Germany
# 462                  New Bedford        MA      50553          USA
# 465                       Madrid      None      28023        Spain
# 471                 Glen Waverly  Victoria       3150    Australia
# 473                        Milan      None       None        Italy
# 475                      Burbank        CA      94019          USA
# 477                     Mannheim      None      68306      Germany
# 480             Saint Petersburg      None     196143       Russia
# 481                      Herzlia      None      47625       Israel
# 484                      Sevilla      None      41101        Spain
# 486                 Philadelphia        PA      71270          USA
# 487                     Brisbane        CA      94217          USA
# 489                       London      None    WA1 1DP           UK
# 495                       Boston        MA      51003          USA
# 496                   Auckland        None       None  New Zealand
#
#                 salesRepEmployeeNumber  creditLimit       contact_full_name
# customerNumber
# 103                             1370.0      21000.0           CarineSchmitt
# 112                             1166.0      71800.0                JeanKing
# 114                             1611.0     117300.0           PeterFerguson
# 119                             1370.0     118200.0           JanineLabrune
# 121                             1504.0      81700.0         JonasBergulfsen
# 124                             1165.0     210500.0             SusanNelson
# 125                                NaN          0.0  ZbyszekPiestrzeniewicz
# 128                             1504.0      59700.0            RolandKeitel
# 129                             1165.0      64600.0             JulieMurphy
# 131                             1323.0     114900.0                 KwaiLee
# 141                             1370.0     227600.0             DiegoFreyre
# 144                             1504.0      53100.0       ChristinaBerglund
# 145                             1401.0      83400.0           JyttePetersen
# 146                             1337.0     123900.0             MarySaveley
# 148                             1621.0     103800.0           EricNatividad
# 151                             1286.0     138500.0               JeffYoung
# 157                             1216.0     100600.0             KelvinLeong
# 161                             1165.0      84600.0           JuriHashimoto
# 166                             1612.0      97900.0          WendyVictorino
# 167                             1504.0      96800.0            VeyselOeztan
# 168                             1286.0          0.0             KeithFranco
# 169                                NaN          0.0         Isabelde Castro
# 171                             1370.0      82900.0            MartineRancé
# 172                             1337.0      84300.0           MarieBertrand
# 173                             1188.0      43400.0              JerryTseng
# 175                             1323.0      84300.0               JulieKing
# 177                             1621.0      81200.0             MoryKentary
# 181                             1286.0      76400.0            MichaelFrick
# 186                             1501.0      96500.0          MattiKarttunen
# 187                             1501.0     136800.0          RachelAshworth
# ...                                ...          ...                     ...
# 386                             1401.0     121400.0          MaurizioMoroni
# 398                             1621.0      94400.0          AkikoShimamura
# 406                             1337.0      95000.0        DominiquePerrier
# 409                                NaN          0.0              RitaMüller
# 412                             1612.0      86800.0              SarahMcRoy
# 415                             1504.0      77000.0      MichaelDonnermeyer
# 424                             1286.0      67500.0          MariaHernandez
# 443                                NaN          0.0          AlexanderFeuer
# 447                             1323.0      49700.0                DanLewis
# 448                             1504.0     116400.0           MarthaLarsson
# 450                             1165.0      77600.0                SueFrick
# 452                             1401.0      45300.0            RolandMendel
# 455                             1286.0      95400.0            LeslieMurphy
# 456                             1286.0      39800.0                  YuChoi
# 458                             1702.0     104600.0            MartínSommer
# 459                                NaN          0.0             SvenOttlieb
# 462                             1216.0      85800.0          VioletaBenitez
# 465                                NaN          0.0             CarmenAnton
# 471                             1611.0      60300.0            SeanClenahan
# 473                             1401.0      34800.0           FrancoRicotti
# 475                             1166.0      55400.0           SteveThompson
# 477                                NaN          0.0               HannaMoos
# 480                                NaN          0.0        AlexanderSemenov
# 481                                NaN          0.0       RaananAltagar,G M
# 484                             1702.0      65700.0          José PedroRoel
# 486                             1323.0      72600.0             RosaSalazar
# 487                             1165.0      60300.0               SueTaylor
# 489                             1501.0      43300.0             ThomasSmith
# 495                             1188.0      85100.0           ValarieFranco
# 496                             1612.0     110000.0             TonySnowden
#
# [122 rows x 13 columns]

# %% [markdown]
# ## Indexando

# %% [markdown]
# ### Indexando una columna
# Al igual que con los objetos básicos de Python (`lists`, `tuples`, `dict`, ...), usamos corchetes (`[]`) para indexar un valor.
#
# * En el caso de un DataFrame, la selección se hace sobre las columas
# * En el caso de un Series, la selección se hace sobre los índices

# %%
# Accediendo a la columna 'city'
customers["city"]
# Out:
# customerNumber
# 103              Nantes
# 112           Las Vegas
# 114           Melbourne
# 119              Nantes
# 121             Stavern
# 124          San Rafael
# 125            Warszawa
# 128           Frankfurt
# 129       San Francisco
# 131                 NYC
# 141              Madrid
# 144               Luleå
# 145           Kobenhavn
# 146                Lyon
# 148           Singapore
# 151                 NYC
# 157           Allentown
# 161          Burlingame
# 166           Singapore
# 167              Bergen
# 168           New Haven
# 169              Lisboa
# 171               Lille
# 172               Paris
# 173           Cambridge
# 175         Bridgewater
# 177             Kita-ku
# 181                 NYC
# 186            Helsinki
# 187          Manchester
#              ...
# 386       Reggio Emilia
# 398           Minato-ku
# 406               Paris
# 409           Stuttgart
# 412          Wellington
# 415              Munich
# 424                 NYC
# 443             Leipzig
# 447            Glendale
# 448              Bräcke
# 450            San Jose
# 452                Graz
# 455           New Haven
# 456                 NYC
# 458              Madrid
# 459              Aachen
# 462         New Bedford
# 465              Madrid
# 471        Glen Waverly
# 473               Milan
# 475             Burbank
# 477            Mannheim
# 480    Saint Petersburg
# 481             Herzlia
# 484             Sevilla
# 486        Philadelphia
# 487            Brisbane
# 489              London
# 495              Boston
# 496          Auckland
# Name: city, Length: 122, dtype: object

# %%
# Accediendo a la columna 'city' (De DataFrame a Series)
#    accedemos posteriormente al índice 486
customers["city"][486]
# Out:
# 'Philadelphia'

# %% [markdown]
# **Nota**: Si la columna a indexar cuenta únicamente con carácteres alfanuméricos y/o guiónes bajos, podemos acceder a la columna de dos manera:
#
# ```python
# df.nombre_columna
# df["nombre_columna"]
# ```

# %% [markdown]
# ### Indexando múltiples columnas
# Para indexar múltples columnas de un pandas DataFrame, es necesario indexar sobre una lista con el nombre de las columnas a indexar.
#
# ```python
#     df[["c0", "c1", ..., "cN"]]
# ```

# %%
customers[["contactLastName", "contactFirstName"]].head()
# Out:
#                contactLastName contactFirstName
# customerNumber
# 103                    Schmitt          Carine
# 112                       King             Jean
# 114                   Ferguson            Peter
# 119                    Labrune          Janine
# 121                 Bergulfsen           Jonas

# %% [markdown]
# ### Deseleccionando Columnas
#
# Para obtener una copia de un DataFrame exceptuando una columna, hacemos uso de método `.drop`
#
# ```python
#     df.drop("ci", axis=1)
# ```
#
# Si queremos la copia de un DataFrame exceptuando más de una columna, hacemos una llamada al método `.drop` con `labels` igual a una lista de las columnas a deseleccionar.
#
# ```python
#     df.drop(["ci", "cj"], axis=1)
# ```

# %%
customers.head(2)
# Out:
#                       customerName contactLastName contactFirstName  \
# customerNumber
# 103              Atelier graphique         Schmitt          Carine
# 112             Signal Gift Stores            King             Jean
#
#                      phone     addressLine1 addressLine2       city state  \
# customerNumber
# 103             40.32.2555   54, rue Royale         None     Nantes  None
# 112             7025551838  8489 Strong St.         None  Las Vegas    NV
#
#                postalCode country  salesRepEmployeeNumber  creditLimit
# customerNumber
# 103                 44000  France                  1370.0      21000.0
# 112                 83030     USA                  1166.0      71800.0

# %%
customers.drop("contactLastName", axis=1).head(2)
# Out:
#                       customerName contactFirstName       phone  \
# customerNumber
# 103              Atelier graphique          Carine   40.32.2555
# 112             Signal Gift Stores             Jean  7025551838
#
#                    addressLine1 addressLine2       city state postalCode  \
# customerNumber
# 103              54, rue Royale         None     Nantes  None      44000
# 112             8489 Strong St.         None  Las Vegas    NV      83030
#
#                country  salesRepEmployeeNumber  creditLimit
# customerNumber
# 103             France                  1370.0      21000.0
# 112                USA                  1166.0      71800.0

# %%
customers.drop(["contactLastName", "contactFirstName"], axis=1).head(2)
# Out:
#                       customerName       phone     addressLine1 addressLine2  \
# customerNumber
# 103              Atelier graphique  40.32.2555   54, rue Royale         None
# 112             Signal Gift Stores  7025551838  8489 Strong St.         None
#
#                      city state postalCode country  salesRepEmployeeNumber  \
# customerNumber
# 103                Nantes  None      44000  France                  1370.0
# 112             Las Vegas    NV      83030     USA                  1166.0
#
#                 creditLimit
# customerNumber
# 103                 21000.0
# 112                 71800.0

# %% [markdown]
# ### Otras Maneras de Indexar
#
# Para indexar un DataFrame sobre sus filas hacemos uso de los operadores `loc` y `iloc`. Estos operadores nos permiten seleccionar un subconjunto de valores tanto de filas como de columnas.
#
# * `loc`: Selección por nombre de los ejes
# * `iloc`: Selección por posición de los ejes

# %%
# Seleccionamos al cliente con id = 112
customers.loc[112]
# Out:
# customerName              Signal Gift Stores
# contactLastName                         King
# contactFirstName                        Jean
# phone                             7025551838
# addressLine1                 8489 Strong St.
# addressLine2                            None
# city                               Las Vegas
# state                                     NV
# postalCode                             83030
# country                                  USA
# salesRepEmployeeNumber                  1166
# creditLimit                            71800
# Name: 112, dtype: object

# %%
# Seleccionamos al cliente dentro de la posición 112 (id = 475)
customers.iloc[112]
# Out:
# customerName              West Coast Collectables Co.
# contactLastName                              Thompson
# contactFirstName                                Steve
# phone                                      3105553722
# addressLine1                        3675 Furth Circle
# addressLine2                                     None
# city                                          Burbank
# state                                              CA
# postalCode                                      94019
# country                                           USA
# salesRepEmployeeNumber                           1166
# creditLimit                                     55400
# Name: 475, dtype: object

# %% [markdown]
# ### Otros Ejemplos con `loc` y `iloc`

# %%
# Seleccionando clientes con id 103 y 112
customers.loc[[103, 112]]
# Out:
#                       customerName contactLastName contactFirstName  \
# customerNumber
# 103              Atelier graphique         Schmitt          Carine
# 112             Signal Gift Stores            King             Jean
#
#                      phone     addressLine1 addressLine2       city state  \
# customerNumber
# 103             40.32.2555   54, rue Royale         None     Nantes  None
# 112             7025551838  8489 Strong St.         None  Las Vegas    NV
#
#                postalCode country  salesRepEmployeeNumber  creditLimit
# customerNumber
# 103                 44000  France                  1370.0      21000.0
# 112                 83030     USA                  1166.0      71800.0

# %%
# Seleccionando el nombre de los clientes con id 103 y 112;
customers.loc[[103, 112], "contactFirstName"]
# Out:
# customerNumber
# 103    Carine
# 112       Jean
# Name: contactFirstName, dtype: object

# %%
# Seleccionando el nombre y apellido de clientes con id 103 y 112
# SELECT customerNumber, contactFirstName, contactLastName
# FROM customers
# where customerNumber = 103 or customerNumber = 112;
customers.loc[[103, 112], ["contactFirstName", "contactLastName"]]
# Out:
#                contactFirstName contactLastName
# customerNumber
# 103                     Carine          Schmitt
# 112                        Jean            King

# %% [markdown]
# ### Indexando condicionalmente

# %%
customers[customers["creditLimit"] < 21e3].head()
# Out:
#                               customerName  contactLastName contactFirstName  \
# customerNumber
# 125                     Havel & Zbyszek Co  Piestrzeniewicz         Zbyszek
# 168                 American Souvenirs Inc           Franco            Keith
# 169                      Porto Imports Co.        de Castro          Isabel
# 206             Asian Shopping Network, Co           Walker           Brydey
# 219                      Boards & Toys Co.            Young             Mary
#
#                          phone            addressLine1 addressLine2  \
# customerNumber
# 125              (26) 642-7555         ul. Filtrowa 68         None
# 168                 2035557845       149 Spinnaker Dr.    Suite 101
# 169               (1) 356-5555  Estrada da saúde n. 58         None
# 206             +612 9411 1555      Suntec Tower Three    8 Temasek
# 219                 3105552373        4097 Douglas Av.         None
#
#                      city state postalCode    country  salesRepEmployeeNumber  \
# customerNumber
# 125              Warszawa  None     01-012     Poland                     NaN
# 168             New Haven    CT      97823        USA                  1286.0
# 169                Lisboa  None       1756   Portugal                     NaN
# 206             Singapore  None     038988  Singapore                     NaN
# 219              Glendale    CA      92561        USA                  1166.0
#
#                 creditLimit
# customerNumber
# 125                     0.0
# 168                     0.0
# 169                     0.0
# 206                     0.0
# 219                 11000.0

# %%
customers.loc[customers["creditLimit"] < 21e3, ["country", "city"]].head()
# Out:
#                   country       city
# customerNumber
# 125                Poland   Warszawa
# 168                   USA  New Haven
# 169              Portugal     Lisboa
# 206             Singapore  Singapore
# 219                   USA   Glendale

# %% [markdown]
# ### El método `query`

# %%
customers.query("country == 'USA' & state == 'NY'")[["customerName"]]
# Out:
#                         customerName
# customerNumber
# 131                Land of Toys Inc.
# 151               Muscle Machine Inc
# 181                  Vitachrome Inc.
# 319                    Mini Classics
# 424             Classic Legends Inc.
# 456                  Microscale Inc.

# %% [markdown]
# ## Operaciones por agrupación
#
# La agrupación de información es una parte esencial en cualquier proceso de análisis de datos para la visualización de información, creación de reportes y búsqueda de patrones.

# %%
query = "SELECT * FROM payments"
payments = pd.read_sql(query, conn, index_col="checkNumber")
payments.head()
# Out:
#              customerNumber paymentDate    amount
# checkNumber
# HQ336336                103  2004-10-19   6066.78
# JM555205                103  2003-06-05  14571.44
# OM314933                103  2004-12-18   1676.14
# BO864823                112  2004-12-17  14191.12
# HQ55022                 112  2003-06-06  32641.98

# %% [markdown]
# ### `Groupby`: split-apply-combine
#
# Una primera manera de hacer un resumen de la información es por medio del método `groupby`. La manera más sencilla de usar `groupby` es seleccionando el nombre de la columna sobre la cuál se hará la agrupación

# %%
# Split: Seleccionamos la columa sobre la cuál
#        estaremos agrupando información.
payments.groupby("customerNumber")

# %% [markdown]
# Al hacer un `groupby`, pandas se prepara para realizar la agrupación de información, mas no la hace hasta aplicar la operación.
#
# * count
# * sum
# * mean
# * median
# * min
# * max
# * var
# * std
# * prod

# %%
payments.groupby("customerNumber").mean()
# Out:
#                       amount
# customerNumber
# 103              7438.120000
# 112             26726.993333
# 114             45146.267500
# 119             38983.226667
# 121             26056.197500
# 124             64909.804444
# 128             18984.440000
# 129             22236.853333
# 131             35879.980000
# 141             55056.844615
# 144             21840.325000
# 145             26861.625000
# 146             43435.116667
# 148             39062.757500
# 151             44478.487500
# 157             49254.625000
# 161             26136.305000
# 166             35140.190000
# 167             48781.235000
# 171             30890.850000
# 172             28851.173333
# 173             16099.345000
# 175             31808.210000
# 177             31180.610000
# 181             24165.880000
# 186             31848.820000
# 187             49470.030000
# 189             24949.135000
# 198              7184.753333
# 201             30583.590000
# ...                      ...
# 357             28331.190000
# 362             16766.735000
# 363             38816.430000
# 379             24511.216667
# 381              7304.295000
# 382             28353.333333
# 385             29156.100000
# 386             45071.655000
# 398             26387.182500
# 406             28812.323333
# 412             33352.470000
# 415             31310.090000
# 424             23071.443333
# 447             16655.926667
# 448             38388.220000
# 450             59551.380000
# 452             17019.996667
# 455             35189.325000
# 456             14615.215000
# 458             37480.030000
# 462             29542.496667
# 471             22460.380000
# 473             12679.160000
# 475             21874.360000
# 484             25493.925000
# 486             25908.863333
# 487             21285.185000
# 489             14793.075000
# 495             32770.870000
# 496             38165.730000
#
# [98 rows x 1 columns]

# %% [markdown]
# ### Agrupando múltiples operaciones (`.agg`)

# %%
from datetime import datetime
def years(dates, fmt="%Y/%m/%d"):
    return list(dates.values.astype("datetime64[Y]"))

payments.groupby("customerNumber").agg({"amount": ["mean", "std"],
                                        "paymentDate": years})
# Out:
#                       amount                \
#                         mean           std
# customerNumber
# 103              7438.120000   6556.113221
# 112             26726.993333  10862.120597
# 114             45146.267500  30498.326741
# 119             38983.226667  16890.337130
# 121             26056.197500  21038.290490
# 124             64909.804444  32471.057547
# 128             18984.440000  12249.126232
# 129             22236.853333   5070.523753
# 131             35879.980000  13874.783230
# 141             55056.844615  31167.974438
# 144             21840.325000  20032.879583
# 145             26861.625000  20545.990802
# 146             43435.116667   5389.024425
# 148             39062.757500  48534.413614
# 151             44478.487500  18398.264067
# 157             49254.625000  19943.953834
# 161             26136.305000  22399.964283
# 166             35140.190000  11293.577191
# 167             48781.235000  51255.660339
# 171             30890.850000  16819.185329
# 172             28851.173333  24935.208527
# 173             16099.345000   6018.744429
# 175             31808.210000   9048.179275
# 177             31180.610000  22623.146073
# 181             24165.880000  19499.928417
# 186             31848.820000   7324.996927
# 187             49470.030000   2973.950819
# 189             24949.135000  10733.322324
# 198              7184.753333   2144.391326
# 201             30583.590000   9440.370504
# ...                      ...           ...
# 357             28331.190000  11470.898336
# 362             16766.735000   2414.027196
# 363             38816.430000  24869.715220
# 379             24511.216667  10601.882246
# 381              7304.295000   6910.270967
# 382             28353.333333  19313.593307
# 385             29156.100000  19071.403340
# 386             45071.655000   9259.372381
# 398             26387.182500  20401.268686
# 406             28812.323333  18767.450659
# 412             33352.470000   2378.848633
# 415             31310.090000           NaN
# 424             23071.443333   2116.753161
# 447             16655.926667   9841.783725
# 448             38388.220000  14738.481199
# 450             59551.380000           NaN
# 452             17019.996667   9302.371091
# 455             35189.325000   4171.724948
# 456             14615.215000  18293.269622
# 458             37480.030000  17883.061346
# 462             29542.496667  19200.036810
# 471             22460.380000  18448.769475
# 473             12679.160000   7165.961542
# 475             21874.360000  20076.331295
# 484             25493.925000  31139.943196
# 486             25908.863333  20047.452259
# 487             21285.185000  12320.494205
# 489             14793.075000  10582.072184
# 495             32770.870000  37468.555959
# 496             38165.730000  12158.829358
#
#                                                       paymentDate
#                                                             years
# customerNumber
# 103                                            [2004, 2003, 2004]
# 112                                            [2004, 2003, 2004]
# 114                                      [2003, 2004, 2003, 2004]
# 119                                            [2004, 2004, 2005]
# 121                                      [2003, 2003, 2004, 2004]
# 124             [2005, 2004, 2003, 2005, 2004, 2004, 2003, 200...
# 128                                      [2003, 2003, 2004, 2004]
# 129                                            [2004, 2003, 2003]
# 131                                            [2003, 2004, 2004]
# 141             [2003, 2004, 2005, 2004, 2004, 2005, 2005, 200...
# 144                                                  [2004, 2003]
# 145                                      [2004, 2004, 2004, 2003]
# 146                                            [2004, 2004, 2003]
# 148                                      [2003, 2004, 2003, 2005]
# 151                                      [2003, 2004, 2003, 2004]
# 157                                                  [2004, 2004]
# 161                                      [2004, 2003, 2005, 2003]
# 166                                            [2004, 2004, 2004]
# 167                                                  [2004, 2003]
# 171                                                  [2004, 2003]
# 172                                            [2004, 2004, 2003]
# 173                                                  [2004, 2004]
# 175                                            [2005, 2003, 2004]
# 177                                                  [2004, 2004]
# 181                                            [2004, 2003, 2004]
# 186                                            [2005, 2003, 2004]
# 187                                            [2004, 2004, 2003]
# 189                                                  [2004, 2004]
# 198                                            [2004, 2003, 2004]
# 201                                                  [2003, 2004]
# ...                                                           ...
# 357                                                  [2003, 2004]
# 362                                                  [2004, 2004]
# 363                                            [2004, 2003, 2003]
# 379                                            [2005, 2003, 2004]
# 381                                      [2004, 2003, 2005, 2003]
# 382                                            [2003, 2004, 2004]
# 385                                            [2003, 2004, 2003]
# 386                                                  [2003, 2004]
# 398                                      [2005, 2004, 2005, 2004]
# 406                                            [2005, 2004, 2004]
# 412                                                  [2004, 2004]
# 415                                                        [2004]
# 424                                            [2004, 2003, 2003]
# 447                                            [2003, 2003, 2004]
# 448                                                  [2005, 2004]
# 450                                                        [2004]
# 452                                            [2003, 2003, 2005]
# 455                                                  [2003, 2004]
# 456                                                  [2004, 2004]
# 458                                            [2004, 2004, 2003]
# 462                                            [2005, 2003, 2004]
# 471                                                  [2004, 2003]
# 473                                                  [2004, 2003]
# 475                                                  [2003, 2004]
# 484                                                  [2004, 2003]
# 486                                            [2004, 2004, 2003]
# 487                                                  [2003, 2004]
# 489                                                  [2003, 2004]
# 495                                                  [2003, 2004]
# 496                                            [2005, 2003, 2004]
#
# [98 rows x 3 columns]

# %% [markdown]
# Groupby nos permite agrupar por más de una columna. En este caso, el resultado es un `MultiIndex` pandas DataFrame.

# %%
customers.groupby(["salesRepEmployeeNumber", "country"]).mean()
# Out:
#                                       creditLimit
# salesRepEmployeeNumber country
# 1165.0                 USA          100433.333333
# 1166.0                 USA           65266.666667
# 1188.0                 USA           73916.666667
# 1216.0                 USA           81533.333333
# 1286.0                 Canada        48700.000000
#                        USA           69600.000000
# 1323.0                 Canada        89950.000000
#                        USA           77866.666667
# 1337.0                 France        86233.333333
# 1370.0                 France        69150.000000
#                        Spain        227600.000000
# 1401.0                 Austria       58500.000000
#                        Belgium       51700.000000
#                        Denmark      102100.000000
#                        Italy         97200.000000
# 1501.0                 Finland       95266.666667
#                        UK            88740.000000
# 1504.0                 Germany       85700.000000
#                        Ireland       69400.000000
#                        Norway        81700.000000
#                        Norway        95950.000000
#                        Sweden        84750.000000
# 1611.0                 Australia     86060.000000
# 1612.0                 New Zealand   90625.000000
#                        Singapore     97900.000000
# 1621.0                 Hong Kong     58600.000000
#                        Japan         87800.000000
#                        Philippines   81500.000000
#                        Singapore    103800.000000
# 1702.0                 Spain         72550.000000
#                        Switzerland   70650.000000

# %% [markdown]
# ### Tablas Dinámicas
#
# Otra manera de agrupar información es por medio de un tabla dinámica (*pivot table*). Una tabla dinámica hace un resumen de la información tomando en cuenta columnas, índices y valores a agrupar

# %%
(payments.assign(year=lambda v: v["paymentDate"].astype("datetime64[Y]"))
         .pivot_table(index="customerNumber", columns="year", values="amount", aggfunc="sum")).head()
# Out:
# year            2003-01-01  2004-01-01  2005-01-01
# customerNumber
# 103               14571.44     7742.92         NaN
# 112               32641.98    47539.00         NaN
# 114               53429.11   127155.96         NaN
# 119                    NaN    67426.01    49523.67
# 121               51710.33    52514.46         NaN

# %% [markdown]
# ## Agrupando DataFrames: join y merge
#
# En ocasiones en las que sea necesario agrupar dos DataFrames, pandas ofrece dos alternativas para relacionar los dataframes: `merge` y `join`. Su uso es muy similar a un `join` en SQL.
#
# * `join` es especialmente útil si se desea hacer una relación entre índices. Al aplicar un `join` a un DataFrame, el DataFrame objetivo deberá tener como índice los valores a unir
# * `merge` es más flexible que `join`, pero con la misma funcionalidad: `merge` nos permite relacionar dos DataFrames por columnas y/o índices.
#
# ```python
# # Ejemlo de join: automáticamente hace la relación entre índice
# # a menos que se indique lo contrario
# df1.join(df2, how="left")
# ```
#
# ```python
# # Ejemplo de merge: Declaramos la columna o nombre de índice
# # sobre la cuál se hará la relación
# df1.merge(df2, how="left", on="col_name")
# ```

# %% [markdown]
# Recordemos los dos DataFrames que tenemos:

# %%
customers.head()
# Out:
#                               customerName contactLastName contactFirstName  \
# customerNumber
# 103                      Atelier graphique         Schmitt          Carine
# 112                     Signal Gift Stores            King             Jean
# 114             Australian Collectors, Co.        Ferguson            Peter
# 119                      La Rochelle Gifts         Labrune          Janine
# 121                     Baane Mini Imports      Bergulfsen           Jonas
#
#                        phone                  addressLine1 addressLine2  \
# customerNumber
# 103               40.32.2555                54, rue Royale         None
# 112               7025551838               8489 Strong St.         None
# 114             03 9520 4555             636 St Kilda Road      Level 3
# 119               40.67.8555  67, rue des Cinquante Otages         None
# 121               07-98 9555        Erling Skakkes gate 78         None
#
#                      city     state postalCode    country  \
# customerNumber
# 103                Nantes      None      44000     France
# 112             Las Vegas        NV      83030        USA
# 114             Melbourne  Victoria       3004  Australia
# 119                Nantes      None      44000     France
# 121               Stavern      None       4110     Norway
#
#                 salesRepEmployeeNumber  creditLimit
# customerNumber
# 103                             1370.0      21000.0
# 112                             1166.0      71800.0
# 114                             1611.0     117300.0
# 119                             1370.0     118200.0
# 121                             1504.0      81700.0

# %%
payments.head()
# Out:
#              customerNumber paymentDate    amount
# checkNumber
# HQ336336                103  2004-10-19   6066.78
# JM555205                103  2003-06-05  14571.44
# OM314933                103  2004-12-18   1676.14
# BO864823                112  2004-12-17  14191.12
# HQ55022                 112  2003-06-06  32641.98

# %% [markdown]
# <h3 style="color:teal">Ejemplo</h3>
#
# Obteniendo el nombre del comprador con mayor número de compras

# %%
(payments.merge(customers[["customerName"]], on="customerNumber")
         .groupby("customerName")
         .mean()
         .sort_values("customerNumber", ascending=False)
         .drop("customerNumber", axis=1))
# Out:
#                                       amount
# customerName
# Kelly's Gift Shop               38165.730000
# Diecast Collectables            32770.870000
# Double Decker Gift Stores, Ltd  14793.075000
# Signal Collectibles Ltd.        21285.185000
# Motor Mint Distributors Inc.    25908.863333
# ...                                      ...
# Baane Mini Imports              26056.197500
# La Rochelle Gifts               38983.226667
# Australian Collectors, Co.      45146.267500
# Signal Gift Stores              26726.993333
# Atelier graphique                7438.120000
#
# [98 rows x 1 columns]

# %% [markdown]
# <h3 style="color:teal">Ejemplo</h3>
#
# Top 10 países con factura más alta en promedio

# %%
(payments.merge(customers[["country"]], on="customerNumber")
         .groupby("country")[["amount"]]
         .mean()
         .sort_values("amount", ascending=False)
         .iloc[:10])
# Out:
#                    amount
# country
# Switzerland  54388.960000
# Hong Kong    45480.790000
# Spain        43236.457826
# Norway       41655.377500
# Singapore    37381.657143
# Italy        36139.394444
# New Zealand  35680.599091
# Denmark      32892.716667
# Finland      32794.372222
# USA          32688.489462

# %% [markdown]
# ## Visualizando Resultados
#
# Un pandas DataFrame cuenta con el método `.plot` el cuál nos permite graficar los valores de nuestro DataFrame por medio de matplotlib.

# %%
import matplotlib.pyplot as plt

plt.rcParams["figure.figsize"] = (18, 4)
# %config InlineBackend.figure_format = "retina"

# %%
(payments.query("customerNumber == 141")
         .plot(x="paymentDate", y="amount"))
plt.title("Pagos del cliente 141", fontsize=14)
plt.grid(alpha=0.6);

# %%
(payments.query("customerNumber in [124, 141]")
         .pivot_table(index="paymentDate", columns="customerNumber")["amount"][[141, 124]]
         .ffill()
         .plot(style="*-", markersize=7))
plt.grid(alpha=0.6);

# %%
top_country = (payments.merge(customers[["country"]], on="customerNumber")
                       .groupby("country")[["amount"]]
                       .mean()
                       .sort_index())

top_country.plot.bar() ## == top_country.plot(kind="bar")

# %% [markdown]
# <h1 style="color:crimson">Ejercicios</h1>
#
# 1. Considerando el DataFrame `payments`, calcula el valor promedio de la columna `amount` agrupado por `customerNumber` y el año de la compra. **hint:** Considera crear una nueva columna con los años.
#
# ---
#
# 2. En este ejercicio entenderemos más a detalle la funcionalidad de `merge` y `join` considerando los dos DataFrames definidos abajo.
#
# ```python
# df1 = pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K3', 'K4', 'K5'],
#                    'A': ['A0', 'A1', 'A2', 'A3', 'A4', 'A5']})
#
# df2 = pd.DataFrame({'key': ['K0', 'K1', 'K2'],
#                       'B': ['B0', 'B1', 'B2']})
# ```
#
# * Realiza las operaciones `df1.merge(df2, how="left")` y `df1.merge(df2, how="right")`.
#     * ¿Qué diferencias observas?
#     * ¿Qué está haciendo el parámetro `how`?
# * Realiza las operaciones `df1.merge(df2, how="inner")` y `df1.merge(df2, how="outer")`.
#     * ¿Qué diferencias observas?
#     * ¿Qué está haciendo el parámetro `how`?
# * Define dos nuevas variables `df1x, df2x = df1.set_index("key"), df2.set_index("key")`
#     * Realiza la operación `df1.join(df2)`. ¿Qué error arroja? ¿A qué se deberá el problema?
#     * Realiza la operación `df1x.join(df2x)`. ¿Qué arroja?
#
# ---
#
# 3. Considerando los DataFrames `payments` y `customers` encuentra el top 10 de clientes (`customerName`) con factura más alta en promedio (`amount`). Presenta el resultado en un DataFrame con índice `customerName` y columnas `mean` del promedio por factura `amount` y `count`, el número de compras realizadas.
#
# **Hint:** Considera la llave `("amount", "mean")` para ordenar los valores por valor de factura. El resultado final se debería ver como sigue:
#
# <table border="1" class="dataframe">  <thead>    <tr style="text-align: right;">      <th></th>      <th>mean</th>      <th>count</th>    </tr>    <tr>      <th>customerName</th>      <th></th>      <th></th>    </tr>  </thead>  <tbody>    <tr>      <th>Collectable Mini Designs Co.</th>      <td>80375.240000</td>      <td>1</td>    </tr>    <tr>      <th>Corporate Gift Ideas Co.</th>      <td>66170.390000</td>      <td>2</td>    </tr>    <tr>      <th>Mini Gifts Distributors Ltd.</th>      <td>64909.804444</td>      <td>9</td>    </tr>    <tr>      <th>The Sharp Gifts Warehouse</th>      <td>59551.380000</td>      <td>1</td>    </tr>    <tr>      <th>Euro+ Shopping Channel</th>      <td>55056.844615</td>      <td>13</td>    </tr>    <tr>      <th>Vida Sport, Ltd</th>      <td>54388.960000</td>      <td>2</td>    </tr>    <tr>      <th>AV Stores, Co.</th>      <td>49470.030000</td>      <td>3</td>    </tr>    <tr>      <th>Diecast Classics Inc.</th>      <td>49254.625000</td>      <td>2</td>    </tr>    <tr>      <th>Herkku Gifts</th>      <td>48781.235000</td>      <td>2</td>    </tr>    <tr>      <th>King Kong Collectables, Co.</th>      <td>45480.790000</td>      <td>1</td>    </tr>  </tbody></table>
#
# Guarda la información dentro de un DataFrame con nombre `res`. Realiza un scatterplot con el número de facturas en el eje de las $x$ y el valor promedio de facturas en el eje de las $y$. ¿Observas algún patrón?

# %% [markdown]
# ## Referencias
#
# 1. McKinney, Wes. [Python for Data Analysis: Data Wrangling with Pandas, NumPy, and IPython](https://www.oreilly.com/library/view/python-for-data/9781491957653/). O'Reilly Media, Inc., 2018.
# 2. http://pandas.pydata.org/pandas-docs/stable/
