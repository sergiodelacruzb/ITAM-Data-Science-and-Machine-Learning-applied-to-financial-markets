# %%
from sklearn.preprocessing import OneHotEncoder, PolynomialFeatures
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer, make_column_selector
from sklearn.pipeline import Pipeline
from sklearn.linear_model import Lasso
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_moons
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_validate, train_test_split
from sklearn.ensemble import BaggingClassifier
from sklearn.metrics import confusion_matrix

import numpy as np
import matplotlib.pyplot as plt


import sys
sys.path.append("../files")
import utils
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-30-c35b2c5eb0aa> in <module>
#      17 import sys
#      18 sys.path.append("../files")
# ---> 19 import utils
#
# ModuleNotFoundError: No module named 'utils'

# %%
X, y = make_moons(200, noise=0.2, random_state=2718)
X_test, y_test = make_moons(40, noise=0.2, random_state=31415)

plt.scatter(*X.T, c=y, cmap="Set2")

# %%
# Create and fit model
model = Pipeline([
    ("poly", PolynomialFeatures(degree=30, include_bias=False)),
    ("logistic", LogisticRegression(penalty='none', multi_class='multinomial'))
])
model.fit(X, y)

# bagging classifier 
bagging_logreg = BaggingClassifier(model, n_estimators=100, random_state=314)
bagging_logreg.fit(X, y)
# Out:
# /Users/sergio.delacruz/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /Users/sergio.delacruz/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 4))

utils.plot_classf_model(X, y, model, ax=ax[0], contour=True)
utils.plot_classf_model(X, y, bagging_logreg, ax=ax[1], contour=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-235e7e00585c> in <module>
#       1 fig, ax = plt.subplots(1, 2, figsize=(12, 4))
#       2
# ----> 3 utils.plot_classf_model(X, y, model, ax=ax[0], contour=True)
#       4 utils.plot_classf_model(X, y, bagging_logreg, ax=ax[1], contour=True)
#
# NameError: name 'utils' is not defined

# %%
ytest_pred = model.predict(X)
print(confusion_matrix(ytest, ytest_pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-514cba3879a5> in <module>
#       1 ytest_pred = model.predict(X)
# ----> 2 print(confusion_matrix(ytest, ytest_pred))
#
# NameError: name 'ytest' is not defined

# %%
ytest_pred = bagging_logreg.predict(X)
print(confusion_matrix(ytest, ytest_pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-ba7758c28e16> in <module>
#       1 ytest_pred = bagging_logreg.predict(X)
# ----> 2 print(confusion_matrix(ytest, ytest_pred))
#
# NameError: name 'ytest' is not defined

# %%
X, y = make_moons(200, noise=0.2, random_state=2718)
X_test, y_test = make_moons(40, noise=0.2, random_state=31415)

plt.scatter(*X.T, c=y, cmap="Set2")

# %%
from sklearn.tree import DecisionTreeClassifier

G, alpha, errs = [], [], []
w = np.ones_like(y) / len(y)
M = 20

for m in range(M):
    Gm = DecisionTreeClassifier(max_depth=1, random_state=314)
    Gm.fit(X, y, sample_weight=w)
    yhat = Gm.predict(X)
    I = (y!=yhat) * 1.0
    err_m = (I * w).sum() / w.sum()
    alpha_m = np.log((1-err_m) / err_m)
    w * np.exp(alpha_m * I)
    
    G.append(Gm)
    alpha.append(alpha_m)
    errs.append(err_m)

# %%
err_train, err_test = [], []
M = 20

for m in range(1, M+1):
    tree = DecisionTreeClassifier(max_depth=2, random_state=314)
    ada = clf = AdaBoostClassifier(tree, algorithm='SAMME', n_estimators=m)
    ada.fit(X, y)
    yhat_acc = accuracy_score(y, ada.predict(X))
    ytest_acc = accuracy_score(y_test, ada.predict(X_test))
    
    err_train.append(yhat_acc)
    err_test.append(ytest_acc)

# %%
plt.plot(err_train, label="train")
plt.plot(err_test, label="test")
plt.legend(fontsize=15)

# %%
fig, ax = plt.subplots()
utils.plot_classf_model(X)
